# %% [markdown]
# DEEP REINFORCEMENT LEARNING EXPLAINED - 15 - 16 - 17
# # **Deep Q-Network (DQN)**

# %% [markdown]
# OpenAI Breakout

# %%
# !pip install gym[atari,accept-rom-license]==0.21.0

# %%
import gym
import gym.spaces

DEFAULT_ENV_NAME = "Breakout-v0" 
test_env = gym.make(DEFAULT_ENV_NAME)
print(test_env.action_space.n)
# Out:
# 4

# %%
print(test_env.unwrapped.get_action_meanings())
# Out:
# ['NOOP', 'FIRE', 'RIGHT', 'LEFT']

# %%
print(test_env.observation_space.shape)
# Out:
# (210, 160, 3)

# %% [markdown]
# Type of hardware accelerator provided by Colab

# %%
# !nvidia-smi
# Out:
# Sat Jun  4 10:04:29 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 471.41       Driver Version: 471.41       CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:08:00.0  On |                  N/A |
# |  0%   46C    P2    27W / 100W |   3780MiB /  4096MiB |     27%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1364    C+G   Insufficient Permissions        N/A      |
# |    0   N/A  N/A      2116    C+G   ...2txyewy\TextInputHost.exe    N/A      |
# |    0   N/A  N/A      7064    C+G   ...icrosoft VS Code\Code.exe    N/A      |
# |    0   N/A  N/A      8372    C+G   C:\Windows\explorer.exe         N/A      |
# |    0   N/A  N/A      8376    C+G   Insufficient Permissions        N/A      |
# |    0   N/A  N/A      8472    C+G   Insufficient Permissions        N/A      |
# |    0   N/A  N/A     10324      C   ...3\envs\pytorch\python.exe    N/A      |
# |    0   N/A  N/A     10848    C+G   ...5n1h2txyewy\SearchApp.exe    N/A      |
# |    0   N/A  N/A     11204    C+G   ...8wekyb3d8bbwe\GameBar.exe    N/A      |
# |    0   N/A  N/A     11572    C+G   ...5n1h2txyewy\SearchApp.exe    N/A      |
# |    0   N/A  N/A     11596    C+G   ...ekyb3d8bbwe\YourPhone.exe    N/A      |
# |    0   N/A  N/A     12460      C   ...3\envs\pytorch\python.exe    N/A      |
# |    0   N/A  N/A     13148    C+G   ...perience\NVIDIA Share.exe    N/A      |
# |    0   N/A  N/A     14788    C+G   ...erver\YourPhoneServer.exe    N/A      |
# |    0   N/A  N/A     16352    C+G   ...IR iCUE Software\iCUE.exe    N/A      |
# |    0   N/A  N/A     16468    C+G   ...les\NZXT CAM\NZXT CAM.exe    N/A      |
# |    0   N/A  N/A     16552    C+G   ...8wekyb3d8bbwe\Cortana.exe    N/A      |
# |    0   N/A  N/A     21084    C+G   ...ser\Application\brave.exe    N/A      |
# |    0   N/A  N/A     23864    C+G   ...lPanel\SystemSettings.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## OpenAI Gym Wrappers

# %%
# Taken from 
# https://github.com/PacktPublishing/Deep-Reinforcement-Learning-Hands-On/blob/master/Chapter06/lib/wrappers.py

import cv2
import numpy as np
import collections

class FireResetEnv(gym.Wrapper):
    def __init__(self, env=None):
        super(FireResetEnv, self).__init__(env)
        assert env.unwrapped.get_action_meanings()[1] == 'FIRE'
        assert len(env.unwrapped.get_action_meanings()) >= 3

    def step(self, action):
        return self.env.step(action)

    def reset(self):
        self.env.reset()
        obs, _, done, _ = self.env.step(1)
        if done:
            self.env.reset()
        obs, _, done, _ = self.env.step(2)
        if done:
            self.env.reset()
        return obs

class MaxAndSkipEnv(gym.Wrapper):
    def __init__(self, env=None, skip=4):
        super(MaxAndSkipEnv, self).__init__(env)
        # most recent raw observations (for max pooling across time steps)
        self._obs_buffer = collections.deque(maxlen=2)
        self._skip = skip

    def step(self, action):
        total_reward = 0.0
        done = None
        for _ in range(self._skip):
            obs, reward, done, info = self.env.step(action)
            self._obs_buffer.append(obs)
            total_reward += reward
            if done:
                break
        max_frame = np.max(np.stack(self._obs_buffer), axis=0)
        return max_frame, total_reward, done, info

    def reset(self):
        self._obs_buffer.clear()
        obs = self.env.reset()
        self._obs_buffer.append(obs)
        return obs


class ProcessFrame84(gym.ObservationWrapper):
    def __init__(self, env=None):
        super(ProcessFrame84, self).__init__(env)
        self.observation_space = gym.spaces.Box(low=0, high=255, shape=(84, 84, 1), dtype=np.uint8)

    def observation(self, obs):
        return ProcessFrame84.process(obs)

    @staticmethod
    def process(frame):
        if frame.size == 210 * 160 * 3:
            img = np.reshape(frame, [210, 160, 3]).astype(np.float32)
        elif frame.size == 250 * 160 * 3:
            img = np.reshape(frame, [250, 160, 3]).astype(np.float32)
        else:
            assert False, "Unknown resolution."
        img = img[:, :, 0] * 0.299 + img[:, :, 1] * 0.587 + img[:, :, 2] * 0.114
        resized_screen = cv2.resize(img, (84, 110), interpolation=cv2.INTER_AREA)
        x_t = resized_screen[18:102, :]
        x_t = np.reshape(x_t, [84, 84, 1])
        return x_t.astype(np.uint8)


class BufferWrapper(gym.ObservationWrapper):
    def __init__(self, env, n_steps, dtype=np.float32):
        super(BufferWrapper, self).__init__(env)
        self.dtype = dtype
        old_space = env.observation_space
        self.observation_space = gym.spaces.Box(old_space.low.repeat(n_steps, axis=0),
                                                old_space.high.repeat(n_steps, axis=0), dtype=dtype)

    def reset(self):
        self.buffer = np.zeros_like(self.observation_space.low, dtype=self.dtype)
        return self.observation(self.env.reset())

    def observation(self, observation):
        self.buffer[:-1] = self.buffer[1:]
        self.buffer[-1] = observation
        return self.buffer


class ImageToPyTorch(gym.ObservationWrapper):
    def __init__(self, env):
        super(ImageToPyTorch, self).__init__(env)
        old_shape = self.observation_space.shape
        self.observation_space = gym.spaces.Box(low=0.0, high=1.0, shape=(old_shape[-1], 
                                old_shape[0], old_shape[1]), dtype=np.float32)

    def observation(self, observation):
        return np.moveaxis(observation, 2, 0)


class ScaledFloatFrame(gym.ObservationWrapper):
    def observation(self, obs):
        return np.array(obs).astype(np.float32) / 255.0

def make_env(env_name,render_mode=None):
    if render_mode:
        env = gym.make(env_name, full_action_space=True, render_mode=render_mode)
    else:
        env = gym.make(env_name, full_action_space=True)
    env = MaxAndSkipEnv(env)
    env = FireResetEnv(env)
    env = ProcessFrame84(env)
    env = ImageToPyTorch(env)
    env = BufferWrapper(env, 4)
    return ScaledFloatFrame(env)

# %% [markdown]
# ## The DQN model

# %%
import torch
import torch.nn as nn        # Pytorch neural network package
import torch.optim as optim  # Pytorch optimization package

device = torch.device("cuda")

# %%
# Taken from 
# https://github.com/PacktPublishing/Deep-Reinforcement-Learning-Hands-On/blob/master/Chapter06/lib/dqn_model.py

import numpy as np

class DQN(nn.Module):
    def __init__(self, input_shape, n_actions):
        super(DQN, self).__init__()

        self.conv = nn.Sequential(
            nn.Conv2d(input_shape[0], 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU()
        )

        conv_out_size = self._get_conv_out(input_shape)
        self.fc = nn.Sequential(
            nn.Linear(conv_out_size, 512),
            nn.ReLU(),
            nn.Linear(512, n_actions)
        )

    def _get_conv_out(self, shape):
        o = self.conv(torch.zeros(1, *shape))
        return int(np.prod(o.size()))

    def forward(self, x):
        conv_out = self.conv(x).view(x.size()[0], -1)
        return self.fc(conv_out)

# %%
test_env = make_env(DEFAULT_ENV_NAME)
test_net = DQN(test_env.observation_space.shape, test_env.action_space.n).to(device)
print(test_net)
# Out:
# DQN(
#   (conv): Sequential(
#     (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (5): ReLU()
#   )
#   (fc): Sequential(
#     (0): Linear(in_features=3136, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=18, bias=True)
#   )
# )

# %% [markdown]
# ## Training

# %% [markdown]
# Load Tensorboard extension

# %%
from torch.utils.tensorboard import SummaryWriter
# %load_ext tensorboard

# %% [markdown]
# Import required modules and define the hyperparameters

# %%
import time
import numpy as np
import collections


MEAN_REWARD_BOUND = 19.0           

gamma = 0.99                   
batch_size = 32
replay_size = 10000            
learning_rate = 1e-4           
sync_target_frames = 1000      
replay_start_size = 10000      

eps_start=0.05
eps_decay=.999985
eps_min=0.05

kskip=0

# %% [markdown]
# Experience replay buffer

# %%
Experience = collections.namedtuple('Experience', field_names=['state', 'action', 'reward', 'done', 'new_state'])

class ExperienceReplay:
    def __init__(self, capacity):
        self.buffer = collections.deque(maxlen=capacity)

    def __len__(self):
        return len(self.buffer)

    def append(self, experience):
        self.buffer.append(experience)

    def sample(self, batch_size):
        indices = np.random.choice(len(self.buffer), batch_size, replace=False)
        states, actions, rewards, dones, next_states = zip(*[self.buffer[idx] for idx in indices])
        return np.array(states), np.array(actions), np.array(rewards, dtype=np.float32), \
               np.array(dones, dtype=np.uint8), np.array(next_states)

# %% [markdown]
# Agent

# %%
class Agent:
    def __init__(self, env, exp_buffer):
        self.env = env
        self.exp_buffer = exp_buffer
        self._reset()

    def _reset(self):
        self.state = env.reset()
        self.total_reward = 0.0

    def play_step(self, net, epsilon=0.0, device="cpu"):

        done_reward = None
        if np.random.random() < epsilon:
            action = env.action_space.sample()
        else:
            state_a = np.array([self.state], copy=False)
            state_v = torch.tensor(state_a).to(device)
            q_vals_v = net(state_v)
            _, act_v = torch.max(q_vals_v, dim=1)
            action = int(act_v.item())

        new_state, reward, is_done, _ = self.env.step(action)
        self.total_reward += reward

        exp = Experience(self.state, action, reward, is_done, new_state)
        self.exp_buffer.append(exp)
        self.state = new_state
        if is_done:
            done_reward = self.total_reward
            self._reset()
        return done_reward

# %%
import datetime
print(">>>Training starts at ",datetime.datetime.now())
# Out:
# >>>Training starts at  2022-06-04 10:04:30.716206

# %% [markdown]
# Main training loop

# %%
continue_training = False

# %%
env = make_env(DEFAULT_ENV_NAME)

net = DQN(env.observation_space.shape, env.action_space.n).to(device)

if continue_training:
    model = DEFAULT_ENV_NAME +'-best.dat'
    net.load_state_dict(torch.load(model, map_location=lambda storage, loc: storage))
    epsilon = 0.05
else:
    epsilon = eps_start
target_net = DQN(env.observation_space.shape, env.action_space.n).to(device)
writer = SummaryWriter(comment="-" + DEFAULT_ENV_NAME)
 
buffer = ExperienceReplay(replay_size)
agent = Agent(env, buffer)


optimizer = optim.Adam(net.parameters(), lr=learning_rate)
total_rewards = []
frame_idx = 0  

best_mean_reward = None
frame_skip_num=kskip

while True:
    frame_idx += 1
    if frame_idx % sync_target_frames == 0:
        target_net.load_state_dict(net.state_dict())
    frame_skip_num = kskip
    epsilon = max(epsilon*eps_decay, eps_min)

    reward = agent.play_step(net, epsilon, device=device)
    if reward is not None:
        total_rewards.append(reward)

        mean_reward = np.mean(total_rewards[-100:])

        print("%d:  %d games, mean reward %.3f, (epsilon %.2f)" % (
            frame_idx, len(total_rewards), mean_reward, epsilon))
        
        writer.add_scalar("epsilon", epsilon, frame_idx)
        writer.add_scalar("reward_100", mean_reward, frame_idx)
        writer.add_scalar("reward", reward, frame_idx)

        if best_mean_reward is None or best_mean_reward < mean_reward:
            torch.save(net.state_dict(), DEFAULT_ENV_NAME + "-best.dat")
            best_mean_reward = mean_reward
            if best_mean_reward is not None:
                print("Best mean reward updated %.3f" % (best_mean_reward))

        if mean_reward > MEAN_REWARD_BOUND:
            print("Solved in %d frames!" % frame_idx)
            break

    if len(buffer) < replay_start_size:
        continue

    if frame_skip_num > 1:
        frame_skip_num -= 1
        continue

    batch = buffer.sample(batch_size)
    states, actions, rewards, dones, next_states = batch

    states_v = torch.tensor(states).to(device)
    next_states_v = torch.tensor(next_states).to(device)
    actions_v = torch.tensor(actions).to(device)
    rewards_v = torch.tensor(rewards).to(device)
    done_mask = torch.ByteTensor(dones).to(device)

    state_action_values = net(states_v).gather(1, actions_v.unsqueeze(-1).to(torch.int64)).squeeze(-1)

    next_state_values = target_net(next_states_v).max(1)[0]

    next_state_values[done_mask] = 0.0

    next_state_values = next_state_values.detach()

    expected_state_action_values = next_state_values * gamma + rewards_v

    loss_t = nn.MSELoss()(state_action_values, expected_state_action_values)

    optimizer.zero_grad()
    loss_t.backward()
    optimizer.step()

writer.close()
# Out:
# 165:  1 games, mean reward 2.000, (epsilon 0.05)
# Best mean reward updated 2.000
# 354:  2 games, mean reward 2.000, (epsilon 0.05)
# 570:  3 games, mean reward 2.333, (epsilon 0.05)
# Best mean reward updated 2.333
# 762:  4 games, mean reward 2.250, (epsilon 0.05)
# 1031:  5 games, mean reward 2.000, (epsilon 0.05)
# 1192:  6 games, mean reward 1.833, (epsilon 0.05)
# 1268:  7 games, mean reward 1.857, (epsilon 0.05)
# 1423:  8 games, mean reward 1.875, (epsilon 0.05)
# 1656:  9 games, mean reward 2.444, (epsilon 0.05)
# Best mean reward updated 2.444
# 1876:  10 games, mean reward 2.400, (epsilon 0.05)
# 2161:  11 games, mean reward 2.545, (epsilon 0.05)
# Best mean reward updated 2.545
# 2350:  12 games, mean reward 2.583, (epsilon 0.05)
# Best mean reward updated 2.583
# 2512:  13 games, mean reward 2.538, (epsilon 0.05)
# 2717:  14 games, mean reward 2.500, (epsilon 0.05)
# 2870:  15 games, mean reward 2.333, (epsilon 0.05)
# 3025:  16 games, mean reward 2.250, (epsilon 0.05)
# 3204:  17 games, mean reward 2.176, (epsilon 0.05)
# 3425:  18 games, mean reward 2.167, (epsilon 0.05)
# 3548:  19 games, mean reward 2.421, (epsilon 0.05)
# 3736:  20 games, mean reward 2.350, (epsilon 0.05)
# 3857:  21 games, mean reward 2.333, (epsilon 0.05)
# 4067:  22 games, mean reward 2.273, (epsilon 0.05)
# 4208:  23 games, mean reward 2.217, (epsilon 0.05)
# 4333:  24 games, mean reward 2.125, (epsilon 0.05)
# 4521:  25 games, mean reward 2.160, (epsilon 0.05)
# 4677:  26 games, mean reward 2.192, (epsilon 0.05)
# 4894:  27 games, mean reward 2.148, (epsilon 0.05)
# 5124:  28 games, mean reward 2.107, (epsilon 0.05)
# 27564:  280 games, mean reward 2.730, (epsilon 0.05)
# Best mean reward updated 2.730
# 27683:  281 games, mean reward 2.780, (epsilon 0.05)
# Best mean reward updated 2.780
# 27787:  282 games, mean reward 2.820, (epsilon 0.05)
# Best mean reward updated 2.820
# 27861:  283 games, mean reward 2.830, (epsilon 0.05)
# Best mean reward updated 2.830
# 27953:  284 games, mean reward 2.850, (epsilon 0.05)
# Best mean reward updated 2.850
# 28032:  285 games, mean reward 2.860, (epsilon 0.05)
# Best mean reward updated 2.860
# 28188:  286 games, mean reward 2.890, (epsilon 0.05)
# Best mean reward updated 2.890
# 28257:  287 games, mean reward 2.890, (epsilon 0.05)
# 28334:  288 games, mean reward 2.900, (epsilon 0.05)
# Best mean reward updated 2.900
# 28418:  289 games, mean reward 2.870, (epsilon 0.05)
# 28493:  290 games, mean reward 2.890, (epsilon 0.05)
# 28600:  291 games, mean reward 2.930, (epsilon 0.05)
# Best mean reward updated 2.930
# 28669:  292 games, mean reward 2.920, (epsilon 0.05)
# 28768:  293 games, mean reward 2.930, (epsilon 0.05)
# 28843:  294 games, mean reward 2.940, (epsilon 0.05)
# Best mean reward updated 2.940
# 28902:  295 games, mean reward 2.940, (epsilon 0.05)
# 28983:  296 games, mean reward 2.960, (epsilon 0.05)
# Best mean reward updated 2.960
# 29128:  297 games, mean reward 3.030, (epsilon 0.05)
# Best mean reward updated 3.030
# 29215:  298 games, mean reward 3.040, (epsilon 0.05)
# Best mean reward updated 3.040
# 29360:  299 games, mean reward 3.080, (epsilon 0.05)
# Best mean reward updated 3.080
# 29502:  300 games, mean reward 3.140, (epsilon 0.05)
# Best mean reward updated 3.140
# 29588:  301 games, mean reward 3.170, (epsilon 0.05)
# Best mean reward updated 3.170
# 29656:  302 games, mean reward 3.190, (epsilon 0.05)
# Best mean reward updated 3.190
# 29725:  303 games, mean reward 3.180, (epsilon 0.05)
# 29794:  304 games, mean reward 3.210, (epsilon 0.05)
# Best mean reward updated 3.210
# 29863:  305 games, mean reward 3.200, (epsilon 0.05)
# 29931:  306 games, mean reward 3.210, (epsilon 0.05)
# 30000:  307 games, mean reward 3.190, (epsilon 0.05)
# 30094:  308 games, mean reward 3.230, (epsilon 0.05)
# Best mean reward updated 3.230
# 30173:  309 games, mean reward 3.250, (epsilon 0.05)
# Best mean reward updated 3.250
# 30289:  310 games, mean reward 3.280, (epsilon 0.05)
# Best mean reward updated 3.280
# 30401:  311 games, mean reward 3.330, (epsilon 0.05)
# Best mean reward updated 3.330
# 30469:  312 games, mean reward 3.340, (epsilon 0.05)
# Best mean reward updated 3.340
# 30543:  313 games, mean reward 3.350, (epsilon 0.05)
# Best mean reward updated 3.350
# 30610:  314 games, mean reward 3.350, (epsilon 0.05)
# 30678:  315 games, mean reward 3.360, (epsilon 0.05)
# Best mean reward updated 3.360
# 30784:  316 games, mean reward 3.390, (epsilon 0.05)
# Best mean reward updated 3.390
# 30854:  317 games, mean reward 3.400, (epsilon 0.05)
# Best mean reward updated 3.400
# 89544:  830 games, mean reward 6.250, (epsilon 0.05)
# 89713:  831 games, mean reward 6.270, (epsilon 0.05)
# 89882:  832 games, mean reward 6.290, (epsilon 0.05)
# 90092:  833 games, mean reward 6.270, (epsilon 0.05)
# 90217:  834 games, mean reward 6.310, (epsilon 0.05)
# 90348:  835 games, mean reward 6.310, (epsilon 0.05)
# 90477:  836 games, mean reward 6.340, (epsilon 0.05)
# 90585:  837 games, mean reward 6.360, (epsilon 0.05)
# Best mean reward updated 6.360
# 90889:  838 games, mean reward 6.360, (epsilon 0.05)
# 91029:  839 games, mean reward 6.380, (epsilon 0.05)
# Best mean reward updated 6.380
# 91132:  840 games, mean reward 6.380, (epsilon 0.05)
# 91275:  841 games, mean reward 6.420, (epsilon 0.05)
# Best mean reward updated 6.420
# 91366:  842 games, mean reward 6.440, (epsilon 0.05)
# Best mean reward updated 6.440
# 91494:  843 games, mean reward 6.440, (epsilon 0.05)
# 91614:  844 games, mean reward 6.500, (epsilon 0.05)
# Best mean reward updated 6.500
# 91788:  845 games, mean reward 6.570, (epsilon 0.05)
# Best mean reward updated 6.570
# 91904:  846 games, mean reward 6.560, (epsilon 0.05)
# 92133:  847 games, mean reward 6.540, (epsilon 0.05)
# 92196:  848 games, mean reward 6.490, (epsilon 0.05)
# 92287:  849 games, mean reward 6.490, (epsilon 0.05)
# 92411:  850 games, mean reward 6.500, (epsilon 0.05)
# 92525:  851 games, mean reward 6.490, (epsilon 0.05)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Ben\workspace\masters\csc570\570FinalProject\DRL_DQN_breakout.ipynb Cell 28' in <cell line: 26>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Ben/workspace/masters/csc570/570FinalProject/DRL_DQN_breakout.ipynb#ch0000027?line=58'>59</a> batch = buffer.sample(batch_size)
#      <a href='vscode-notebook-cell:/c%3A/Users/Ben/workspace/masters/csc570/570FinalProject/DRL_DQN_breakout.ipynb#ch0000027?line=59'>60</a> states, actions, rewards, dones, next_states = batch
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Ben/workspace/masters/csc570/570FinalProject/DRL_DQN_breakout.ipynb#ch0000027?line=61'>62</a> states_v = torch.tensor(states).to(device)
#      <a href='vscode-notebook-cell:/c%3A/Users/Ben/workspace/masters/csc570/570FinalProject/DRL_DQN_breakout.ipynb#ch0000027?line=62'>63</a> next_states_v = torch.tensor(next_states).to(device)
#      <a href='vscode-notebook-cell:/c%3A/Users/Ben/workspace/masters/csc570/570FinalProject/DRL_DQN_breakout.ipynb#ch0000027?line=63'>64</a> actions_v = torch.tensor(actions).to(device)
#
# KeyboardInterrupt:

# %% [markdown]
# 6000  games - 1.5 hours
#
# 11000 games - 3 hours
#
# 21000 games - a lot of hours no better performance

# %% [markdown]
# 12000 games - 158 min

# %%
print(">>>Training ends at ",datetime.datetime.now())
# Out:
# >>>Training ends at  2022-06-03 14:43:41.816318

# %% [markdown]
# Performance

# %%
tensorboard  --logdir=runs
# Out:
# Reusing TensorBoard on port 6006 (pid 2708), started 3:46:13 ago. (Use '!kill 2708' to kill it.)
#       <iframe id="tensorboard-frame-d9541b5e3be25ab1" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-d9541b5e3be25ab1");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
